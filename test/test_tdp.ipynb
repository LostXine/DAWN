# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from dawn.models.system2.tdp import TransformerDiffusionPolicy

# %%
model = TransformerDiffusionPolicy(obs_dim=768, goal_dim=768).cuda()
# Out:
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTModel: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# obs dim: 768, goal_dim: 768, action_dim: 7, proprio_dim: 8
# seq_size: 14

# %%
img = torch.rand(2, 5, 256, 256, device="cuda")
latent_goal = torch.rand(2, 12, 768, device="cuda")
x = {
    "visual_input": img,
    "lang_goal": latent_goal,
}
labels = torch.rand(2, 10, 7, device="cuda")

# %%
out = model(x, labels)

# %%
out
# Out:
# {'loss': tensor(1.1514, device='cuda:0', grad_fn=<MeanBackward0>)}

# %%
model.eval()
out = model.forward(x, labels)

# %%
out
# Out:
# {'logits': tensor([[[-0.0195,  0.3516,  0.4250,  0.1265, -0.3381,  0.1052,  0.1069],
#           [-0.0106,  0.3133,  0.4294,  0.0569, -0.3647,  0.1333,  0.0889],
#           [ 0.0145,  0.3390,  0.4484,  0.0860, -0.3822,  0.0892,  0.1060],
#           [ 0.0126,  0.3218,  0.4799,  0.0797, -0.4341,  0.1231,  0.1246],
#           [ 0.0226,  0.3256,  0.4715,  0.0822, -0.4378,  0.1206,  0.1149],
#           [ 0.0175,  0.3160,  0.4643,  0.0815, -0.4244,  0.0960,  0.1061],
#           [ 0.0188,  0.3467,  0.4617,  0.0832, -0.4207,  0.0985,  0.0978],
#           [ 0.0130,  0.3476,  0.4430,  0.0952, -0.4139,  0.0912,  0.1020],
#           [ 0.0255,  0.3339,  0.4556,  0.0928, -0.4035,  0.1085,  0.1147],
#           [ 0.0275,  0.3234,  0.4597,  0.0973, -0.3887,  0.1058,  0.1099]],
#
#          [[-0.0153,  0.1158,  0.4106,  0.0576, -0.3659,  0.1445,  0.1211],
#           [-0.0333,  0.1722,  0.4614,  0.1521, -0.4643,  0.1308,  0.1102],
# ...

# %%
out.shape
# Out:
# torch.Size([2, 10, 7])
